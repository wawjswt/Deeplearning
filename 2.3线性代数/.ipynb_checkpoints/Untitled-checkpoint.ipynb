# %%
import torch

# %%
m=torch.tensor(
[[1,3,4,2],
[3.0,4,6,1],
[1,6,2,1.0],
[6,7,8,9],
[2,3,4,1]
])

# %%
m.shape
# Out:
# torch.Size([5, 4])

# %%
m.sum(axis=0)/m
# Out:
# tensor([[13.0000,  7.6667,  6.0000,  7.0000],
#         [ 4.3333,  5.7500,  4.0000, 14.0000],
#         [13.0000,  3.8333, 12.0000, 14.0000],
#         [ 2.1667,  3.2857,  3.0000,  1.5556],
#         [ 6.5000,  7.6667,  6.0000, 14.0000]])

# %%
m.sum(axis=1)
# Out:
# tensor([10., 14., 10., 30., 10.])

# %%
m.sum(axis=0,keepdims=True)/m
# Out:
# tensor([[13.0000,  7.6667,  6.0000,  7.0000],
#         [ 4.3333,  5.7500,  4.0000, 14.0000],
#         [13.0000,  3.8333, 12.0000, 14.0000],
#         [ 2.1667,  3.2857,  3.0000,  1.5556],
#         [ 6.5000,  7.6667,  6.0000, 14.0000]])
