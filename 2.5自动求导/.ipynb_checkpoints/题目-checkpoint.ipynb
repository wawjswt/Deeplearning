# %%
import torch

x = torch.arange(4, dtype=torch.float, requires_grad=True)
y = 3 * torch.dot(x, x)
y.backward()
print(x.grad)
print(torch.allclose(x.grad, 6 * x))
# Out:
# tensor([ 0.,  6., 12., 18.])
# True

# %%
x = torch.arange(4, dtype=torch.float, requires_grad=True)
y = 3 * torch.matmul(x, x)
y.backward()
print(x.grad)
print(torch.allclose(x.grad, 6 * x))
# Out:
# tensor([ 0.,  6., 12., 18.])
# True

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
y = 2 * torch.dot(x, x)
y.backward()
print(x.grad)
# tensor([4.0, 8.0, 12.0])
# Out:
# tensor([ 4.,  8., 12.])

# %%
x = torch.tensor([1.0, 2.0], requires_grad=True)

y1 = (x * x).sum()
y1.backward()
print(x.grad)

y2 = x.sum()
y2.backward() #y2=x1+x2, 梯度应该是[1,1]

print(x.grad,'# 梯度没清理')


x.grad.zero_()
y2 = x.sum()
y2.backward() #y2=x1+x2, 梯度应该是[1,1]

print(x.grad, '正确结果')
# Out:
# tensor([2., 4.])
# tensor([3., 5.]) # 梯度没清理
# tensor([1., 1.]) 正确结果

# %%
# 求和函数的梯度，与向量x取值无关
x = torch.tensor([2.0, -1.0, 5.0], requires_grad=True)
y = x.sum()
y.backward()
x.grad
# Out:
# tensor([1., 1., 1.])

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
y = x * x # y是向量，对应元素平方的向量，无法反向传播，报错，因此要求和
y.sum().backward() #y.sum()=x1**2+x2**2+x3**2
x.grad
# Out:
# tensor([2., 4., 6.])

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)
y = x * x # y是向量，对应元素平方的向量，无法反向传播，报错，因此可以引用一个 likey 的全1张量
y.backward(torch.ones_like(y))
x.grad
# Out:
# tensor([2., 4., 6.])

# %%
x = torch.tensor([2.0, 3.0], requires_grad=True)
y = x * x
u = y.detach()
z = u * x
z.sum().backward()
print(x.grad)
# Out:
# tensor([4., 9.])

# %%
x = torch.tensor([2.0, 3.0], requires_grad=True)
y = x * x
z = y.detach() * x
z.sum().backward()
x.grad #[4,9]
# Out:
# tensor([4., 9.])

# %%
x = torch.tensor([2.0, 3.0], requires_grad=True)
y = x * x
z = y * x
z.sum().backward()
x.grad #[12,27]
# Out:
# tensor([12., 27.])

# %%
x=torch.tensor([1.0],  requires_grad=True)
y=2*x
z=y**3
z.backward()
x.grad
# Out:
# tensor([24.])

# %%
PyTorch 使用动态计算图。每次调用 f(a) 时，程序会根据当前输入实际执行一定次数的循环并选择一个分支。
PyTorch只记录本次运行中真正执行过的张量运算，并据此构建计算图。因此，即使不同输入产生不同的执行路径，PyTorch 仍可在本次构建的计算图上使用链式法则完成反向传播。
也就是说，即使是分段函数，也能够根据实际落在哪一段进行求导
# Out:
#   Cell In[47], line 1
#     PyTorch 使用动态计算图。每次调用 f(a) 时，程序会根据当前输入实际执行一定次数的循环并选择一个分支。
#                    ^
# SyntaxError: invalid character '。' (U+3002)

# %%
x = torch.tensor(2.0, requires_grad=True)
y = 3 * x
z = y ** 2
z.backward()
x.grad, y.grad
# Out:
# C:\Users\11485\AppData\Local\Temp\ipykernel_20168\3363107373.py:5: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at C:\cb\pytorch_1000000000000\work\build\aten\src\ATen/core/TensorBody.h:494.)
#   x.grad, y.grad
# (tensor(36.), None)

# %%
# 报错因为y不是叶子张量，不会保留梯度，如果确实需要查看中间张量的梯度，可以在反向传播前调用：

x = torch.tensor(2.0, requires_grad=True)
y = 3 * x
z = y ** 2
y.retain_grad()
z.backward()
x.grad, y.grad
# Out:
# (tensor(36.), tensor(12.))

# %%
requires_grad_(True) 用于开启梯度跟踪，retain_grad() 用于保留非叶子张量的梯度。
# Out:
#   Cell In[51], line 1
#     requires_grad_(True) 用于开启梯度跟踪，retain_grad() 用于保留非叶子张量的梯度。
#                                  ^
# SyntaxError: invalid character '，' (U+FF0C)

# %%
#正向传播一次，构建一次计算图，执行反向传播一次，计算图摧毁
x = torch.tensor(2.0, requires_grad=True)
y = x ** 2
y.backward()
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[54], line 5
#       3 y = x ** 2
#       4 y.backward()
# ----> 5 y.backward()
#
# File E:\Anaconda\envs\AI\Lib\site-packages\torch\_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File E:\Anaconda\envs\AI\Lib\site-packages\torch\autograd\__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
# ...

# %%
x = torch.tensor(2.0, requires_grad=True)
y = x ** 2
y.backward(retain_graph=True) #保留计算图，但会导致梯度累加
y.backward()
x.grad
# Out:
# tensor(8.)

# %%
x = torch.tensor(2.0, requires_grad=True)

y = x ** 2
y.backward()

x.grad.zero_()
y = x ** 2
y.backward()
x.grad
# Out:
# tensor(4.)

# %%
x = torch.tensor([1,2,3], dtype=torch.float, requires_grad=True)

z = 2*x**3 + 5*x
L=z.sum()
L.backward()
x.grad
# Out:
# tensor([11., 29., 59.])

# %%
# 15
x = torch.tensor([1.0, 2.0], requires_grad=True)

y = x ** 2
u = y.detach() #u=[1,4]
loss1 = (u * x).sum()
loss1.backward()

first_grad = x.grad.clone() #[1,4]
x.grad.zero_()

loss2 = (x ** 3).sum() 
loss2.backward()
second_grad = x.grad.clone() #[3,12]

first_grad, second_grad
# Out:
# (tensor([1., 4.]), tensor([ 3., 12.]))

# %%
import math
x = torch.tensor([1,2,3], dtype=torch.float, requires_grad=True)
y=torch.exp(x)
y.sum().backward()
x.grad==y
# Out:
# tensor([True, True, True])
